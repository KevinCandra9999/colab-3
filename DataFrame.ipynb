# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinCandra9999/colab-3/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from urllib.request import urlopen
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ### Mengenal dan membuat DataFrame

# %%
pd.read_csv('https://thinkjubilee.com/sekolah.csv')
# Out:
#                 Provinsi     SD    SMP    SMA     PT
# 0                   ACEH  99.85  98.09  82.15  34.28
# 1         SUMATERA UTARA  99.49  96.60  76.76  26.80
# 2         SUMATERA BARAT  99.50  96.29  82.86  35.45
# 3                   RIAU  98.98  94.73  76.52  27.28
# 4                  JAMBI  99.59  95.89  71.54  24.12
# 5       SUMATERA SELATAN  99.63  94.01  69.05  19.17
# 6               BENGKULU  99.80  97.20  79.07  29.90
# 7                LAMPUNG  99.78  94.76  70.03  20.96
# 8   KEP. BANGKA BELITUNG  99.64  92.41  66.99  14.99
# 9              KEP. RIAU  99.32  99.08  82.80  19.13
# 10           DKI JAKARTA  99.67  97.64  71.50  24.60
# 11            JAWA BARAT  99.51  93.77  66.62  21.50
# 12           JAWA TENGAH  99.62  95.48  68.48  22.13
# 13         DI YOGYAKARTA  99.87  99.63  87.61  51.33
# 14            JAWA TIMUR  99.57  96.77  71.51  23.34
# 15                BANTEN  99.31  95.67  67.77  21.33
# 16                  BALI  99.44  97.72  82.16  26.56
# ...

# %%
pendidikan = pd.read_csv('https://thinkjubilee.com/sekolah.csv')

# %%
type(pendidikan)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Drop pada kolom

# %%
nama = ['Joni','Jono','Jana','Jini','Junu']
usia = [20,22,24,26,28]
menikah = [False,True,True,False,True]

# %%
df = pd.DataFrame ({'nama' : nama, 'usia' : usia, 'menikah' : menikah})

# %%
df
# Out:
#    nama  usia  menikah
# 0  Joni    20    False
# 1  Jono    22     True
# 2  Jana    24     True
# 3  Jini    26    False
# 4  Junu    28     True

# %%
df.drop('nama',axis=1)
# Out:
#    usia  menikah
# 0    20    False
# 1    22     True
# 2    24     True
# 3    26    False
# 4    28     True

# %% [markdown]
# ### sample pada Data (menampilkan data secara acak)

# %%
df.sample(3)
# Out:
#    nama  usia  menikah
# 3  Jini    26    False
# 1  Jono    22     True
# 0  Joni    20    False

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1),
#  Index(['nama', 'usia', 'menikah'], dtype='object')]

# %%
df.axes[0]
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.axes[1]
# Out:
# Index(['nama', 'usia', 'menikah'], dtype='object')

# %%
df.axes[1][2]
# Out:
# 'menikah'

# %%
df.index[2]
# Out:
# 2

# %%
df.columns[2]
# Out:
# 'menikah'

# %%
df
# Out:
#    nama  usia  menikah
# 0  Joni    20    False
# 1  Jono    22     True
# 2  Jana    24     True
# 3  Jini    26    False
# 4  Junu    28     True

# %%
df.loc[2]
# Out:
# nama       Jana
# usia         24
# menikah    True
# Name: 2, dtype: object

# %%
pd.read_csv('https://thinkjubilee.com/sekolah.csv')
# Out:
#                 Provinsi     SD    SMP    SMA     PT
# 0                   ACEH  99.85  98.09  82.15  34.28
# 1         SUMATERA UTARA  99.49  96.60  76.76  26.80
# 2         SUMATERA BARAT  99.50  96.29  82.86  35.45
# 3                   RIAU  98.98  94.73  76.52  27.28
# 4                  JAMBI  99.59  95.89  71.54  24.12
# 5       SUMATERA SELATAN  99.63  94.01  69.05  19.17
# 6               BENGKULU  99.80  97.20  79.07  29.90
# 7                LAMPUNG  99.78  94.76  70.03  20.96
# 8   KEP. BANGKA BELITUNG  99.64  92.41  66.99  14.99
# 9              KEP. RIAU  99.32  99.08  82.80  19.13
# 10           DKI JAKARTA  99.67  97.64  71.50  24.60
# 11            JAWA BARAT  99.51  93.77  66.62  21.50
# 12           JAWA TENGAH  99.62  95.48  68.48  22.13
# 13         DI YOGYAKARTA  99.87  99.63  87.61  51.33
# 14            JAWA TIMUR  99.57  96.77  71.51  23.34
# 15                BANTEN  99.31  95.67  67.77  21.33
# 16                  BALI  99.44  97.72  82.16  26.56
# ...

# %%
DataProvinsi = pd.read_csv('https://thinkjubilee.com/sekolah.csv', index_col='Provinsi')

# %%
DataProvinsi.loc['JAMBI']
# Out:
# SD     99.59
# SMP    95.89
# SMA    71.54
# PT     24.12
# Name: JAMBI, dtype: float64

# %%
DataProvinsi.loc['DKI JAKARTA']['SD']
# Out:
# 99.67

# %%
DataProvinsi.loc['DKI JAKARTA':'DI YOGYAKARTA']
# Out:
#                   SD    SMP    SMA     PT
# Provinsi
# DKI JAKARTA    99.67  97.64  71.50  24.60
# JAWA BARAT     99.51  93.77  66.62  21.50
# JAWA TENGAH    99.62  95.48  68.48  22.13
# DI YOGYAKARTA  99.87  99.63  87.61  51.33

# %%
DataProvinsi.loc[['DKI JAKARTA','DI YOGYAKARTA'],['SD','SMP']]
# Out:
#                   SD    SMP
# Provinsi
# DKI JAKARTA    99.67  97.64
# DI YOGYAKARTA  99.87  99.63

# %% [markdown]
# ### Bekerja dengan Dataset

# %%
data_url = 'http://thinkjubilee.com/bola.csv'
pemainbola = pd.read_csv(data_url)

# %%
pemainbola
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %% [markdown]
# ### indexing dengan boolean mask

# %%
pemainbola.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
pemainbola.market_value
# Out:
# 0      65.0
# 1      50.0
# 2       7.0
# 3      20.0
# 4      22.0
#        ...
# 460     5.0
# 461     7.0
# 462     4.5
# 463     1.0
# 464    10.0
# Name: market_value, Length: 465, dtype: float64

# %%
pemainbola.market_value	>= 60
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
pemainbola[pemainbola.market_value > 50]
# Out:
#                 name               club  age position  position_cat  \
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 96       Eden Hazard            Chelsea   26       LW             1
# 244  Kevin De Bruyne    Manchester+City   26       AM             1
# 245    Sergio Aguero    Manchester+City   29       CF             1
# 267       Paul Pogba  Manchester+United   24       CM             2
# 381       Harry Kane          Tottenham   23       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            65.0        4329       12.0  17.10%         264       3
# 96           75.0        4220       10.5   2.30%         224       2
# 244          65.0        2252       10.0  17.50%         199       2
# 245          65.0        4046       11.5   9.70%         175       3
# 267          75.0        7435        8.0  19.50%         115       2
# 381          60.0        4161       12.5  35.10%         224       1
#
# ...

# %%
pemainbola[pemainbola.market_value	== 65].shape
# Out:
# (3, 17)

# %%
pemainbola.nationality.unique()
# Out:
# array(['Chile', 'Germany', 'Czech Republic', 'England', 'France', 'Spain',
#        'Nigeria', 'Switzerland', 'Wales', 'Brazil', 'Egypt', 'Argentina',
#        'Colombia', 'Bosnia', 'Norway', 'Poland', 'Scotland', 'Congo DR',
#        'Ireland', 'Netherlands', 'Australia', "Cote d'Ivoire", 'Finland',
#        'Cameroon', 'Austria', 'Israel', 'Northern Ireland', 'Canada',
#        'Belgium', 'Iceland', 'Serbia', 'Portugal', 'Ghana', 'South Korea',
#        'Mali', 'Senegal', 'Curacao', 'Denmark', 'Slovenia',
#        'Trinidad and Tobago', 'Bermuda', 'Benin', 'Algeria', 'Jamaica',
#        'Japan', 'Tunisia', 'Croatia', 'Estonia', 'Ecuador', 'Armenia',
#        'Italy', 'Sweden', 'United States', 'Morocco', 'The Gambia',
#        'Kenya', 'Greece', 'Uruguay', 'Romania', 'Venezuela',
#        'New Zealand'], dtype=object)

# %%
pemainbola.nationality.unique().size
# Out:
# 61

# %%
pemainbola.nationality.isin(['England', 'South Korea', 'Italy'])
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463     True
# 464    False
# Name: nationality, Length: 465, dtype: bool

# %%
pemainbola[pemainbola.nationality.isin(['England', 'South Korea', 'Italy'])]
# Out:
#                         name      club  age position  position_cat  \
# 3               Theo Walcott   Arsenal   28       RW             1
# 12   Alex Oxlade-Chamberlain   Arsenal   23       RM             2
# 13   Alex Oxlade-Chamberlain   Arsenal   23       RM             2
# 14             Jack Wilshere   Arsenal   25       CM             2
# 18              Kieran Gibbs   Arsenal   27       LB             3
# ..                       ...       ...  ...      ...           ...
# 453             Andy Carroll  West+Ham   28       CF             1
# 455          Aaron Cresswell  West+Ham   27       LB             3
# 458           Angelo Ogbonna  West+Ham   29       CB             3
# 462                Sam Byram  West+Ham   23       RB             3
# 463          Ashley Fletcher  West+Ham   21       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 3            20.0        2393        7.5   1.50%         122       1
# ...

# %% [markdown]
# ### Method Between

# %%
pemainbola[pemainbola.market_value.between(65,75)]
# Out:
#                 name               club  age position  position_cat  \
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 96       Eden Hazard            Chelsea   26       LW             1
# 244  Kevin De Bruyne    Manchester+City   26       AM             1
# 245    Sergio Aguero    Manchester+City   29       CF             1
# 267       Paul Pogba  Manchester+United   24       CM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            65.0        4329       12.0  17.10%         264       3
# 96           75.0        4220       10.5   2.30%         224       2
# 244          65.0        2252       10.0  17.50%         199       2
# 245          65.0        4046       11.5   9.70%         175       3
# 267          75.0        7435        8.0  19.50%         115       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0         Chile            0        4        1         1            0
# ...

# %%
pemainbola[pemainbola.market_value.between(65,75, inclusive=False)]
# Out:
# <ipython-input-37-47f6d8980ea2>:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   pemainbola[pemainbola.market_value.between(65,75, inclusive=False)]
# Empty DataFrame
# Columns: [name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %% [markdown]
# ### method dan comparison operator

# %%
pemainbola[pemainbola.age >= 25].shape
# Out:
# (335, 17)

# %%
pemainbola[pemainbola.age.le(25)].shape
# Out:
# (172, 17)

# %%
pemainbola[pemainbola.age.lt(25)].shape
# Out:
# (130, 17)

# %%
pemainbola[pemainbola.age.gt(25)].shape
# Out:
# (293, 17)

# %%
pemainbola[pemainbola.age.ge(25)].shape
# Out:
# (335, 17)

# %%
pemainbola[pemainbola.age.eq(25)].shape
# Out:
# (42, 17)

# %% [markdown]
# ### MEngkombinasi kondisi

# %%
pemainbola[(pemainbola.market_value.gt(30)) &
            (pemainbola.nationality == 'England')]
# Out:
#                 name             club  age position  position_cat  \
# 246  Raheem Sterling  Manchester+City   22       LW             1
# 256      John Stones  Manchester+City   23       CB             3
# 380        Dele Alli        Tottenham   21       CM             2
# 381       Harry Kane        Tottenham   23       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 246          45.0        2074        8.0   3.80%         149       1
# 256          35.0        1078        5.5   2.30%          59       1
# 380          45.0        4626        9.5  38.60%         225       1
# 381          60.0        4161       12.5  35.10%         224       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 246     England            0        2       11         1            0
# 256     England            0        2       11         1            1
# 380     England            0        1       17         1            0
# ...

# %%
pemainbola[(pemainbola.age.lt(30)) &
            (pemainbola.club == 'Arsenal') &
             (pemainbola.market_value.gt(30))]
# Out:
#                    name     club  age position  position_cat  market_value  \
# 0        Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1            Mesut Ozil  Arsenal   28       AM             1          50.0
# 10         Granit Xhaka  Arsenal   24       DM             2          35.0
# 11         Granit Xhaka  Arsenal   24       DM             2          35.0
# 15         Aaron Ramsey  Arsenal   26       CM             2          35.0
# 31  Alexandre Lacazette  Arsenal   26       CF             1          40.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 0         4329       12.0  17.10%         264       3        Chile
# 1         4395        9.5   5.60%         167       2      Germany
# 10        1815        5.5   2.00%          85       2  Switzerland
# 11        1815        5.5   2.00%          85       2  Switzerland
# 15        1040        7.0   5.10%          56       1        Wales
# ...

# %% [markdown]
# ### Memasukan kondisi kedalam variabel

# %%
usia = pemainbola.age.lt(30)
klub = pemainbola.club == 'Arsenal'
market = pemainbola.market_value.gt(30)
pemainbola[(usia) &
          (klub) &
          (market)]
# Out:
#                    name     club  age position  position_cat  market_value  \
# 0        Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1            Mesut Ozil  Arsenal   28       AM             1          50.0
# 10         Granit Xhaka  Arsenal   24       DM             2          35.0
# 11         Granit Xhaka  Arsenal   24       DM             2          35.0
# 15         Aaron Ramsey  Arsenal   26       CM             2          35.0
# 31  Alexandre Lacazette  Arsenal   26       CF             1          40.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# 0         4329       12.0  17.10%         264       3        Chile
# 1         4395        9.5   5.60%         167       2      Germany
# 10        1815        5.5   2.00%          85       2  Switzerland
# 11        1815        5.5   2.00%          85       2  Switzerland
# 15        1040        7.0   5.10%          56       1        Wales
# ...

# %%
usia = pemainbola.age.lt(30)
klub = pemainbola.club == 'Arsenal'
market = pemainbola.market_value.gt(30)
pemainbola[(usia) |
          (klub) |
          (market)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %% [markdown]
# ### 2d indexing

# %%
usia = pemainbola.age.lt(30)
klub = pemainbola.club == 'Arsenal'
market = pemainbola.market_value.gt(30)
pemainbola.loc[(usia) & (klub) & (market), ['name','age','club','market_value','nationality']]
# Out:
#                    name  age     club  market_value  nationality
# 0        Alexis Sanchez   28  Arsenal          65.0        Chile
# 1            Mesut Ozil   28  Arsenal          50.0      Germany
# 10         Granit Xhaka   24  Arsenal          35.0  Switzerland
# 11         Granit Xhaka   24  Arsenal          35.0  Switzerland
# 15         Aaron Ramsey   26  Arsenal          35.0        Wales
# 31  Alexandre Lacazette   26  Arsenal          40.0       France

# %% [markdown]
# ### melakukan Sorting

# %%
pemainbola.sort_values(by='age', ascending=False)
# Out:
#                        name               club  age position  position_cat  \
# 136          Julian Speroni     Crystal+Palace   38       GK             4
# 35              Artur Boruc        Bournemouth   37       GK             4
# 424          Gareth McAuley          West+Brom   37       CB             3
# 61                    Bruno  Brighton+and+Hove   36       RB             1
# 402          Heurelho Gomes            Watford   36       GK             4
# ..                      ...                ...  ...      ...           ...
# 159         Ademola Lookman            Everton   19       LW             1
# 439           Jonathan Leko          West+Brom   18       RW             1
# 354              Josh Tymon         Stoke+City   18       LB             3
# 235  Trent Alexander-Arnold          Liverpool   18       RB             3
# 237            Ben Woodburn          Liverpool   17       LW             1
#
# ...

# %%
usia = pemainbola.age.lt(30)
klub = pemainbola.club == 'Arsenal'
market = pemainbola.market_value.gt(30)
pemainbola.loc[(usia) & (klub) & (market), ['name','age','club','market_value','nationality']].sort_values(by='age', ascending=False)
# Out:
#                    name  age     club  market_value  nationality
# 0        Alexis Sanchez   28  Arsenal          65.0        Chile
# 1            Mesut Ozil   28  Arsenal          50.0      Germany
# 15         Aaron Ramsey   26  Arsenal          35.0        Wales
# 31  Alexandre Lacazette   26  Arsenal          40.0       France
# 10         Granit Xhaka   24  Arsenal          35.0  Switzerland
# 11         Granit Xhaka   24  Arsenal          35.0  Switzerland

# %% [markdown]
# ### Mencari data dukplikat

# %%
pemainbola[pemainbola.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
pemainbola[pemainbola.duplicated(subset=['club','age','nationality','market_value'], keep='first')]
# Out:
#                         name              club  age position  position_cat  \
# 11              Granit Xhaka           Arsenal   24       DM             2
# 13   Alex Oxlade-Chamberlain           Arsenal   23       RM             2
# 23   Alex Oxlade-Chamberlain           Arsenal   23       RM             2
# 38                Adam Smith       Bournemouth   26       RB             3
# 47             Andrew Surman       Bournemouth   30       CM             2
# 260                 Fernando   Manchester+City   32       DM             2
# 302             Jack Colback  Newcastle+United   27       DM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11           35.0        1815        5.5   2.00%          85       2
# 13           22.0        1519        6.0   1.80%          83       1
# 23           22.0        1519        6.0   1.80%          83       1
# 38            5.0         200        5.0   0.90%         104       1
# ...

# %% [markdown]
# ### mengguranakan drop duplicated

# %%
pemainbola[pemainbola.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
pemainbola.market_value.mean()
# Out:
# 11.125649350649349

# %%
pemainbola.drop_duplicates(keep='first').market_value.mean()
# Out:
# 11.026252723311545

# %% [markdown]
# ### Mengatasi NaN

# %%
pemainbola[pemainbola.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# ...

# %%
pemainbola.fillna({'position' : 'CF',
                   'market_value' : 11}).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       CF             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30           11.0        1815        5.5   2.00%          85       2
# 192          11.0          56        6.0   0.60%           0       2
# 195          11.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# ### menambah kolom baru

# %%
pemainbola ['class'] = 'A'

# %%
pemainbola[pemainbola.market_value > 30]
# Out:
#                     name               club  age position  position_cat  \
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 1             Mesut Ozil            Arsenal   28       AM             1
# 10          Granit Xhaka            Arsenal   24       DM             2
# 11          Granit Xhaka            Arsenal   24       DM             2
# 15          Aaron Ramsey            Arsenal   26       CM             2
# 31   Alexandre Lacazette            Arsenal   26       CF             1
# 96           Eden Hazard            Chelsea   26       LW             1
# 97           Diego Costa            Chelsea   28       CF             1
# 102     Thibaut Courtois            Chelsea   25       GK             4
# 104        Cesc Fabregas            Chelsea   30       CM             2
# 105              Willian            Chelsea   28       RW             1
# 107        Nemanja Matic            Chelsea   28       DM             2
# ...

# %%
pemainbola_kecil = pemainbola.iloc[:5, 0:3]
pemainbola_kecil
# Out:
#                 name     club  age
# 0     Alexis Sanchez  Arsenal   28
# 1         Mesut Ozil  Arsenal   28
# 2          Petr Cech  Arsenal   35
# 3       Theo Walcott  Arsenal   28
# 4  Laurent Koscielny  Arsenal   31

# %%
nickname = pd.Series(['Alex','Mesut','Petr','Theo','Laurent'])
pemainbola_kecil.insert (1, 'nickname', nickname)

# %%
pemainbola_kecil.drop(columns=['nickname'], inplace = True)

# %%
pemainbola_kecil
# Out:
#                 name     club  age
# 0     Alexis Sanchez  Arsenal   28
# 1         Mesut Ozil  Arsenal   28
# 2          Petr Cech  Arsenal   35
# 3       Theo Walcott  Arsenal   28
# 4  Laurent Koscielny  Arsenal   31

# %%
pemainbola_kecil.assign(goals=[15, 20, 0, 11, 14])
# Out:
#                 name     club  age  goals
# 0     Alexis Sanchez  Arsenal   28     15
# 1         Mesut Ozil  Arsenal   28     20
# 2          Petr Cech  Arsenal   35      0
# 3       Theo Walcott  Arsenal   28     11
# 4  Laurent Koscielny  Arsenal   31     14

# %% [markdown]
# ### Menambahkan data baru

# %%
pemainbola_kecil
# Out:
#                 name     club  age
# 0     Alexis Sanchez  Arsenal   28
# 1         Mesut Ozil  Arsenal   28
# 2          Petr Cech  Arsenal   35
# 3       Theo Walcott  Arsenal   28
# 4  Laurent Koscielny  Arsenal   31

# %%
namajoni = pd.Series({
    'name' : 'Jonio Ronaldo',
    'nickname' : 'Joni',
    'club' : 'Arsenal',
    'age' : 20},
    name = 5)

# %%
pemainbola_kecil.append(namajoni)
# Out:
# <ipython-input-67-a7e391474cc9>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pemainbola_kecil.append(namajoni)
#                 name     club  age nickname
# 0     Alexis Sanchez  Arsenal   28      NaN
# 1         Mesut Ozil  Arsenal   28      NaN
# 2          Petr Cech  Arsenal   35      NaN
# 3       Theo Walcott  Arsenal   28      NaN
# 4  Laurent Koscielny  Arsenal   31      NaN
# 5      Jonio Ronaldo  Arsenal   20     Joni

# %%
namapemainbaru = pd.DataFrame({
    'name' : ["Toni Messi", "edi Neymar"],
    'nickname' : ['Toni','Edi'],
    'club' : ['Chelsea','Barcelona'],
    'age' : [21,22]},
      index=[6,7])

# %%
pemainbola_kecil.append(namapemainbaru)
# Out:
# <ipython-input-69-5309d6a200e0>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pemainbola_kecil.append(namapemainbaru)
#                 name       club  age nickname
# 0     Alexis Sanchez    Arsenal   28      NaN
# 1         Mesut Ozil    Arsenal   28      NaN
# 2          Petr Cech    Arsenal   35      NaN
# 3       Theo Walcott    Arsenal   28      NaN
# 4  Laurent Koscielny    Arsenal   31      NaN
# 6         Toni Messi    Chelsea   21     Toni
# 7         edi Neymar  Barcelona   22      Edi

# %% [markdown]
# ### BEKERJA DENGAN BEBRAPA DATAFRAMES

# %%
engineering = 'http://thinkjubilee.com/data/engineering.csv'
state = 'http://thinkjubilee.com/data/state.csv'
ivies = 'http://thinkjubilee.com/data/ivies.csv'
liberalarts = 'http://thinkjubilee.com/data/liberalarts.csv'
wilayah = 'http://thinkjubilee.com/data/regions.csv'

# %%
en = pd.read_csv(engineering)

# %%
en.sort_values(by=['Starting Median Salary'], ascending=False)
# Out:
#                                           School Name  School Type  \
# 1            California Institute of Technology (CIT)  Engineering
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 14          South Dakota School of Mines & Technology  Engineering
# ...

# %%
st = pd.read_csv(state)

# %%
st.sort_values(by=['Starting Median Salary'], ascending=False)
# Out:
#                                   School Name School Type  \
# 0          University of California, Berkeley       State
# 2                    Cal Poly San Luis Obispo       State
# 11       University of Missouri - Rolla (UMR)       State
# 10                      Binghamton University       State
# 12           San Jose State University (SJSU)       State
# ..                                        ...         ...
# 156               Western Carolina University       State
# 148           Missouri State University (MSU)       State
# 168  University of Wisconsin (UW) - Green Bay       State
# 174              Black Hills State University       State
# 169                 Morehead State University       State
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 2              $57,200.00              $101,000.00
# 11             $57,100.00               $95,800.00
# 10             $53,600.00               $95,900.00
# ...

# %%
art = pd.read_csv(liberalarts)

# %%
art.sort_values(by=['Starting Median Salary'], ascending=False)
# Out:
#                                       School Name   School Type  \
# 2                                 Amherst College  Liberal Arts
# 0                             Bucknell University  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 27                               Hamilton College  Liberal Arts
# 20                  Franklin and Marshall College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 16                         University of Richmond  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# ...

# %% [markdown]
# ### Concatenating DataFrames

# %%
pd.concat([en, st])
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 170                  Austin Peay State University        State
# 171                    Pittsburg State University        State
# 172                      Southern Utah University        State
# 173           Montana State University - Billings        State
# 174                  Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# 2              $71,800.00              $122,000.00
# ...

# %%
school = [en, st, art]

# %%
pd.concat(school)
# Out:
#                                      School Name   School Type  \
# 0    Massachusetts Institute of Technology (MIT)   Engineering
# 1       California Institute of Technology (CIT)   Engineering
# 2                            Harvey Mudd College   Engineering
# 3   Polytechnic University of New York, Brooklyn   Engineering
# 4                                   Cooper Union   Engineering
# ..                                           ...           ...
# 42                              Moravian College  Liberal Arts
# 43                         Lewis & Clark College  Liberal Arts
# 44                            Fort Lewis College  Liberal Arts
# 45                        Thomas Aquinas College  Liberal Arts
# 46                       Evergreen State College  Liberal Arts
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# ...

# %% [markdown]
# ### Column Axis Concatenation

# %%
pd.concat((school), axis=0)
# Out:
#                                      School Name   School Type  \
# 0    Massachusetts Institute of Technology (MIT)   Engineering
# 1       California Institute of Technology (CIT)   Engineering
# 2                            Harvey Mudd College   Engineering
# 3   Polytechnic University of New York, Brooklyn   Engineering
# 4                                   Cooper Union   Engineering
# ..                                           ...           ...
# 42                              Moravian College  Liberal Arts
# 43                         Lewis & Clark College  Liberal Arts
# 44                            Fort Lewis College  Liberal Arts
# 45                        Thomas Aquinas College  Liberal Arts
# 46                       Evergreen State College  Liberal Arts
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# ...

# %%
pd.concat([en, art], axis=1)
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %% [markdown]
# ### Outer dan Inner

# %%
en_copy = en.copy()

# %%
en_copy
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
en_copy['location'] = 'USA'

# %%
pd.concat([en_copy, art], join='inner')
# Out:
#                                      School Name   School Type  \
# 0    Massachusetts Institute of Technology (MIT)   Engineering
# 1       California Institute of Technology (CIT)   Engineering
# 2                            Harvey Mudd College   Engineering
# 3   Polytechnic University of New York, Brooklyn   Engineering
# 4                                   Cooper Union   Engineering
# ..                                           ...           ...
# 42                              Moravian College  Liberal Arts
# 43                         Lewis & Clark College  Liberal Arts
# 44                            Fort Lewis College  Liberal Arts
# 45                        Thomas Aquinas College  Liberal Arts
# 46                       Evergreen State College  Liberal Arts
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# ...

# %% [markdown]
# ### Method Merge

# %%
wil = pd.read_csv(wilayah)
wil
# Out:
#                                       School Name        Region
# 0     Massachusetts Institute of Technology (MIT)  Northeastern
# 1        California Institute of Technology (CIT)    California
# 2                             Harvey Mudd College    California
# 3    Polytechnic University of New York, Brooklyn  Northeastern
# 4                                    Cooper Union  Northeastern
# ..                                            ...           ...
# 264                  Austin Peay State University      Southern
# 265                    Pittsburg State University    Midwestern
# 266                      Southern Utah University       Western
# 267           Montana State University - Billings       Western
# 268                  Black Hills State University    Midwestern
#
# [269 rows x 2 columns]

# %%
sekolah = pd.concat((school),axis=0)

# %%
pd.merge(sekolah, wil, on='School Name')
# Out:
#                                       School Name   School Type  \
# 0     Massachusetts Institute of Technology (MIT)   Engineering
# 1        California Institute of Technology (CIT)   Engineering
# 2                             Harvey Mudd College   Engineering
# 3    Polytechnic University of New York, Brooklyn   Engineering
# 4                                    Cooper Union   Engineering
# ..                                            ...           ...
# 256                              Moravian College  Liberal Arts
# 257                         Lewis & Clark College  Liberal Arts
# 258                            Fort Lewis College  Liberal Arts
# 259                        Thomas Aquinas College  Liberal Arts
# 260                       Evergreen State College  Liberal Arts
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $72,200.00              $126,000.00   Northeastern
# ...

# %% [markdown]
# ### Left dan Right Parameter

# %%
income = 'http://thinkjubilee.com/data/gaji.csv'
gaji = pd.read_csv(income)
gaji
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# ...

# %%
pd.merge(sekolah, gaji, left_on='School Name', right_on='school_name').drop('school_name', axis=1)
# Out:
#                                       School Name   School Type  \
# 0     Massachusetts Institute of Technology (MIT)   Engineering
# 1        California Institute of Technology (CIT)   Engineering
# 2                             Harvey Mudd College   Engineering
# 3    Polytechnic University of New York, Brooklyn   Engineering
# 4                                    Cooper Union   Engineering
# ..                                            ...           ...
# 256                              Moravian College  Liberal Arts
# 257                         Lewis & Clark College  Liberal Arts
# 258                            Fort Lewis College  Liberal Arts
# 259                        Thomas Aquinas College  Liberal Arts
# 260                       Evergreen State College  Liberal Arts
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# ...

# %% [markdown]
# ### One-to-One dan One-to-Many

# %%
unik = (pd.merge(st, wil, how='inner', on='School Name').sort_values(by = 'School Name').drop_duplicates())
pd.merge(st, wil, how='inner', on='School Name').sort_values(by = 'School Name').drop_duplicates()
# Out:
#                            School Name School Type Starting Median Salary  \
# 169       Appalachian State University       State            $40,400.00
# 58      Arizona State University (ASU)       State            $47,400.00
# 184    Arkansas State University (ASU)       State            $38,700.00
# 48                   Auburn University       State            $45,400.00
# 189       Austin Peay State University       State            $37,700.00
# ..                                 ...         ...                    ...
# 117             Wayne State University       State            $42,800.00
# 107     West Virginia University (WVU)       State            $43,100.00
# 175        Western Carolina University       State            $36,900.00
# 131  Western Michigan University (WMU)       State            $42,300.00
# 122      Western Washington University       State            $42,700.00
#
#     Mid-Career Median Salary      Region
# 169              $69,100.00     Southern
# ...

# %%
wil['School Name'].is_unique
# Out:
# False

# %%
st['School Name'].is_unique
# Out:
# True

# %%
unik['School Name'].is_unique
# Out:
# True
